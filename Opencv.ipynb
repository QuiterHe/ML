# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t

# %matplotlib inline

# load image
PATH = '/Users/hezhang/Room/ML/img/Lenna.png'
PATH = '/Users/hezhang/Room/ML/vericode/img/813e102b0e8e13c5da780e674afed980.png'
image = cv2.imread(PATH)

# np.savetxt('/Users/hezhang/Room/ML/data/ver.txt', image,  delimiter=",")
# b = np.loadtxt('/Users/hezhang/Room/ML/data/ver.txt')
# print b

    
plt.imshow(image)
plt.show()

# cvtColor
t0 = t.time()
cv_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
t1 = t.time()
dt_cv = t1-t0
print "Conversion took %0.5f seconds" % dt_cv

plt.imshow(cv_rgb)
plt.show()

# Numpy Swap
print "Height:\t\t%i pixels\nWidth:\t\t%i pixels\nChannels:\t%i" % image.shape
# Out:
# Conversion took 0.00017 seconds
# Height:		38 pixels
# Width:		112 pixels
# Channels:	3
